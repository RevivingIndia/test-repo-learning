# %%
API - Application programming Interface
requests - module (consume)

post - create a resource
get  - get all resources/ specifc
put  - update any resources
delete - delete any resources

# %%
x = [1,2,3,4,5] #data - resource
CRUD
