# %%
Data - collection of info , number , raw data,facts which 
can be stored , processed and analyzed 


Datatype  : Data is belong to particular category , that 
category is said to be data
eg : Number , string , collection


variable : any data is stored in container 
that container is said to be data

# %%
praveen = 10
print(praveen)
print(type(praveen))
# Out:
# 10
# <class 'int'>

# %%
x = "123456"
print(x)
print(type(x))
# Out:
# 123456
# <class 'str'>
