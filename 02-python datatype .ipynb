# %%
x = 10 
print(x,id(x))
# Out:
# 10 140712412498648

# %%
x = x+100
print(x,id(x))
# Out:
# 110 140712412501848

# %%
y = [10,20,"hello"]
print(y,id(y))
# Out:
# [10, 20, 'hello'] 1713252543168

# %%
y[0] = 1000
print(y,id(y))
# Out:
# [1000, 20, 'hello'] 1713252543168
