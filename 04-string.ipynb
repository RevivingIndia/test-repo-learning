# %%
#string , tuple
# list , dict & sets

# %%
#string
it is a collection charcaters words & sentences

# %%
#CRUD opeartions
#create
x = "hello"
print(x,type(x))
y = 'hello'
print(y,type(y))
z= '''hello'''
t = """hello"""
print(type(z),type(t))
r = 'h'
print(r,type(r))
# Out:
# hello <class 'str'>
# hello <class 'str'>
# <class 'str'> <class 'str'>
# h <class 'str'>

# %%
#read 
x = "helloworld"
#complete data -helloworld
#single substring - h  - indexing - +ve ,-ve
#mutiple substring - ell  - slicing
print(x)
print(x[2])
print(x[4],x[-10])
# print(x[4444444]) # Index Error
# Out:
# helloworld
# l
# o h

# %%
x = "helloworld" #[start:stop]
print(x[2:4]) # 2 3
print(x[1:5]) #1 2 3 4
print(x[4:4]) 
print(x[3:])
print(x[:2]) #0 1 
print(x[:])
print(x[0:8888888888])
# Out:
# ll
# ello
#
# loworld
# he
# helloworld
# helloworld

# %%
x = "helloworld"
print(x[-5:-2]) #-3 to -5
print(x[-3:-1]) #rl
#rld
print(x[-3:])
# Out:
# wor
# rl
# rld

# %%
#update 
x = "hello"
x[0] = "H"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 #update
#       2 x = "hello"
# ----> 3 x[0] = "H"
#
# TypeError: 'str' object does not support item assignment

# %%
x = "hi"
del x[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 x = "hi"
# ----> 2 del x[0]
#
# TypeError: 'str' object doesn't support item deletion

# %%
#slicing [start:stop]  [start:stop:step]

# %%
x = "helloworld"
print(x[1:4:1])
print(x[0:5:44]) # 0 1 2 3 4
# Out:
# ell
# h
