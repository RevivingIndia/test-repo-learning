# %%
import mysql.connector
#database connection
db = mysql.connector.connect(
    host = "localhost",
    user= "root",
    password= "abc@123",
    database= "ecommerce"
)
cursor = db.cursor()

# %%
cursor.execute("select * from ecommerce.customer limit 2")
a = cursor.fetchall()
print(a)
# Out:
# [(1, 'Praveen', 'Male', 25, 9716817710, 'praveenrrc@gmail.com', 'Delhi', 'Delhi', 'India'), (2, 'Sita', 'Female', 25, 9716817720, 'sita@gmail.com', 'Patna', 'Bihar', 'India')]

# %%
cursor.execute("select * from ecommerce.customer")
a = cursor.fetchall()
print(a)
# Out:
# [(1, 'Praveen', 'Male', 25, 9716817710, 'praveenrrc@gmail.com', 'Delhi', 'Delhi', 'India'), (2, 'Sita', 'Female', 25, 9716817720, 'sita@gmail.com', 'Patna', 'Bihar', 'India'), (3, 'Raman', 'Male', 26, 9716817730, 'raman@gmail.com', 'Agra', 'UP', 'India'), (4, 'Ruman', 'Male', 22, 9716817740, 'ruman@gmail.com', 'Delhi', 'Delhi', 'India'), (5, 'Prateek', 'Male', 21, 9716817750, 'prateek@gmail.com', 'Delhi', 'Delhi', 'India'), (6, 'Heena', 'Female', 25, 9716817790, 'heena@gmail.com', 'Delhi', 'Delhi', 'India'), (601, 'Heena', 'Female', 25, 96817790, 'hee@gmail.com', 'Delhi', 'Delhi', 'India')]
